# %%
#lets import some libraries

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import statsmodels.api as sm
import pandas_profiling as pp

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
dp = pd.read_csv("diamonds.csv")
dp.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
dp.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
dp.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
dp.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
dp["carat"].nunique()
# Out:
# 273

# %%
sns.boxplot(dp["carat"])
# Out:
# <AxesSubplot:xlabel='carat'>

# %%
dp["cut"].dtype
# Out:
# dtype('O')

# %%
s = (dp.dtypes =="object")
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['cut', 'color', 'clarity']

# %%
label_data = dp.copy()

# Apply label encoder to each column with categorical data
label_encoder = LabelEncoder()
for col in object_cols:
    label_data[col] = label_encoder.fit_transform(label_data[col])
label_data.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    2      1        3   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    3      1        2   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    1      1        4   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    3      5        5   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    1      6        3   63.3   58.0    335  4.34  4.35  2.75

# %%
label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  int32
#  2   color    53940 non-null  int32
#  3   clarity  53940 non-null  int32
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int32(3), int64(1)
# memory usage: 3.5 MB

# %%
dp["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
data = label_data.drop(label_data[label_data["x"]==0].index)
data = label_data.drop(label_data[label_data["y"]==0].index)
data = label_data.drop(label_data[label_data["z"]==0].index)

# %%
label_data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
sns.boxplot(label_data["table"])
# Out:
# <AxesSubplot:xlabel='table'>

# %%
cmap = sns.diverging_palette(90,20,s=50, l=40, n=6,as_cmap=True)
corrmat= label_data.corr()
f, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corrmat,cmap=cmap,annot=True, )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## visulaziation

# %%
plt.figure(figsize= (15,10))

sns.lineplot( x = label_data["carat"], y = label_data["price"])

# increase in price as the size of diamond increases
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
plt.figure(figsize= (15,10))

sns.lineplot( x = label_data["carat"], y = label_data["price"])

# %%
sns.boxplot(label_data["x"])
# Out:
# <AxesSubplot:xlabel='x'>

# %%
plt.scatter(x = label_data["price"], y = label_data["y"])
plt.show()

# %%
sns.displot(new_data['y'])

# %%
sm.qqplot(new_data["y"], line = '45', fit = True)

# %%
new_data = label_data[label_data['y']<10]
new_data =new_data[new_data['y']>0]

# %%
plt.scatter(x = new_data["price"], y = new_data["y"])
plt.show()

# %%
sns.scatterplot(y = new_data['x'] , x = new_data['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='x'>

# %%
sm.qqplot(new_data["x"], line = '45', fit = True)

# %%
new_data = new_data[new_data['x']<10]
new_data =new_data[new_data['x']>3]

# %%
sns.scatterplot(y = label_data['y'] , x = label_data['price'],)
# Out:
# <AxesSubplot:xlabel='price', ylabel='y'>

# %%
sns.scatterplot(y = label_data['z'] , x = label_data['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='z'>

# %%
sns.scatterplot(y = new_data['z'] , x = new_data['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='z'>

# %%
new_data = new_data[new_data['z']<7]
new_data =new_data[new_data['z']>2]

# %%
sm.qqplot(new_data["z"], line = '45', fit = True)

# %% [markdown]
# ## Model training

# %%
x = new_data.drop("price", axis = 1)
y = new_data["price"]

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state= 23)

# %%
x_test
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 50453   0.71    2      3        3   61.5   55.0  5.74  5.78  3.54
# 34874   0.30    3      3        7   62.1   59.0  4.27  4.23  2.64
# 23768   1.65    4      4        4   62.0   56.0  7.53  7.59  4.68
# 17864   1.51    1      2        3   63.7   59.0  7.15  7.26  4.59
# 18690   0.32    2      4        7   61.9   53.0  4.42  4.44  2.74
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 32831   0.33    2      4        1   61.8   55.2  4.44  4.47  2.76
# 45996   0.53    4      0        2   60.0   59.8  5.25  5.26  3.15
# 17847   1.07    2      3        4   62.0   56.0  6.58  6.52  4.06
# 53238   0.72    2      2        2   61.5   58.0  5.72  5.76  3.53
# 38825   0.32    2      0        7   61.3   55.8  4.43  4.44  2.71
#
# [10782 rows x 9 columns]

# %%
x_train
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 35235   0.39    1      3        7   63.4   57.0  4.62  4.65  2.94
# 51712   0.78    4      3        3   63.7   55.9  5.82  5.85  3.72
# 30969   0.38    3      5        2   60.5   58.0  4.72  4.67  2.84
# 51797   0.70    3      0        5   61.3   58.0  5.72  5.67  3.48
# 42540   0.50    3      2        5   61.7   60.0  5.06  5.02  3.11
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 9708    0.34    1      2        5   64.3   53.0  4.44  4.48  2.87
# 11196   1.14    4      0        3   59.2   61.0  6.82  6.84  4.04
# 26589   2.03    3      5        5   60.5   62.0  8.22  8.17  4.96
# 9260    1.05    2      3        3   62.3   56.0  6.52  6.58  4.08
# 41582   0.25    4      0        4   60.0   63.0  4.05  4.08  2.44
#
# [43127 rows x 9 columns]

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 12110.981686132203

# %%
model.coef_
# Out:
# array([11790.40152688,    67.61954823,  -271.84611089,   282.04244818,
#          -70.57646138,   -93.3070661 ,  -961.23494332,   463.85776749,
#        -1571.0969899 ])

# %% [markdown]
# ## Test data

# %%
y_predt = model.predict(x_test)

mse = mean_squared_error(y_test, y_predt)
print("Mean squared error is : ", mse)

rmse = np.sqrt(mse)
print("root mean squared error is : ", rmse)

mae = mean_absolute_error(y_test, y_predt)
print("Mean absoulte error: ", mae)

R2_value = r2_score(y_test, y_predt)
print("R2_score is : ", R2_value)
# Out:
# Mean squared error is :  1738640.8985965427
# root mean squared error is :  1318.5753291323717
# Mean absoulte error:  836.7139536865812
# R2_score is :  0.8890540006046086

# %% [markdown]
# ## Training data

# %%
y_predt_train = model.predict(x_train)

mse = mean_squared_error(y_train, y_predt_train)
print("Mean squared error is : ", mse)

rmse = np.sqrt(mse)
print("root mean squared error is : ", rmse)

mae = mean_absolute_error(y_train, y_predt_train)
print("Mean absoulte error: ", mae)

R2_value = r2_score(y_train, y_predt_train)
print("R2_score is : ", R2_value)
# Out:
# Mean squared error is :  1786937.6289685122
# root mean squared error is :  1336.7638643262737
# Mean absoulte error:  848.3738387447853
# R2_score is :  0.8878450382370191

# %%
x_test.head(1)
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 50453   0.71    2      3        3   61.5   55.0  5.74  5.78  3.54

# %%
model.predict([[0.71,2,3,3,61.5,55.0,5.74,5.78,3.54]])
# Out:
# array([2777.57984514])

# %%
y_test.head(1)
# Out:
# 50453    2264
# Name: price, dtype: int64

# %%
import pickle
import json

# %%
with open ("diamond_price.pkl", "wb")as f:
    pickle.dump(model,f)

# %%
with open('project_data.json', 'w') as f:
    json.dump(project_data, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35308/3866079957.py in <module>
#       1 with open('project_data.json', 'w') as f:
# ----> 2     json.dump(project_data, f)
#
# NameError: name 'project_data' is not defined

# %%
profile = pp.ProfileReport(new_data)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile = pp.ProfileReport(dp)
profile.to_file("put.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
